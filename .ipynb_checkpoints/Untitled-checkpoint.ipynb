# %%
# !pip install -r requirements.txt
import pandas as pd
hi=pd.read_csv('images_df.csv')
hi
# Out:
#                                          Recipe  \
# 0                    One-Pot Cheeseburger Pasta
# 1                 One-Pot Broccoli Cheddar Soup
# 2        Vegan Butternut Squash Al Pastor Tacos
# 3                       Honey Soy Glazed Salmon
# 4     Weekday Meal-prep Pesto Chicken & Veggies
# ...                                         ...
# 1319                  Aloo Kurma (Potato Curry)
# 1320                       Stuffed Bell Peppers
# 1321                                 Fried Rice
# 1322                             Matzo Ball Pho
# 1323             Fusilli With Vegan Vodka Sauce
#
#                                              Image Link
# 0     https://img.buzzfeed.com/thumbnailer-prod-us-e...
# 1     https://img.buzzfeed.com/video-api-prod/assets...
# 2     https://img.buzzfeed.com/thumbnailer-prod-us-e...
# 3     https://img.buzzfeed.com/video-api-prod/assets...
# 4                                              no image
# ...

# %% [markdown]
# https://mybinder.org/v2/gh/202103817/202103817.github.io.git/HEAD
